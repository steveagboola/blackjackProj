# %%
#fixing dictionary issues

import random

def house_deals():
    deck_of_cards = {
        "cards_clubs": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_diamonds": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_hearts": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_spades": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    }
    suit = random.choice(list(deck_of_cards.keys()))  #using the list function to get the keys of deck_of_cards
    card = random.choice(deck_of_cards[suit]) #randomly picking value of deck_of cards
    print(f"Dealt card: {card} of {suit}")
    return card
house_deals()
# Out:
# Dealt card: 6 of cards_diamonds
# 6

# %%
import random


def house_deals():
    deck_of_cards = {
        "cards_clubs": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_diamonds": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_hearts": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_spades": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    }
    suit = random.choice(list(deck_of_cards.keys()))  #using the list function to get the keys of deck_of_cards
    card = random.choice(deck_of_cards[suit]) #randomly picking value of deck_of cards
    print(f"Dealt card: {card} of {suit}")
    return card


# Calculatint the score:

def calc_score(deck_of_cards):
    blackjack = sum(deck_of_cards) == 21 and len(deck_of_cards) == 2

    if sum(deck_of_cards) == blackjack:
        return blackjack

    if 11 in deck_of_cards and sum(deck_of_cards) > 21:
        deck_of_cards.remove(11)
        deck_of_cards.apppend(1)
    return sum(deck_of_cards)  # CHECK TO SEE ABOUT THE INDENTATION!!!


house_deals()
# Out:
# Dealt card: 2 of cards_spades
# 2

# %%
import random


def house_deals():
    deck_of_cards = {
        "cards_clubs": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_diamonds": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_hearts": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_spades": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    }
    suit = random.choice(list(deck_of_cards.keys()))  #using the list function to get the keys of deck_of_cards
    card = random.choice(deck_of_cards[suit]) #randomly picking value of deck_of cards
    print(f"Dealt card: {card} of {suit}")
    return card

############################
# Calculatint the score:

#DOES NOT WORK
def calc_score(deck_of_cards):
    blackjack = sum(deck_of_cards) == 21 and len(deck_of_cards) == 2

    if sum(deck_of_cards) == blackjack:
        return blackjack

    if 11 in deck_of_cards and sum(deck_of_cards) > 21:
        deck_of_cards.remove(11)
        deck_of_cards.apppend(1)
    return sum(deck_of_cards) # CHECK TO SEE ABOUT THE INDENTATION!!!

calc_score([2,3])

test = [
    [11,10]
    [2,4]
]

for i in test:
    print(f"{i} {calc_score(i)}")
# Out:
# <>:33: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:33: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# /var/folders/p4/6w50dy6n077b1z2n4wf2nlpc0000gn/T/ipykernel_12599/390047824.py:33: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   [11,10]
# /var/folders/p4/6w50dy6n077b1z2n4wf2nlpc0000gn/T/ipykernel_12599/390047824.py:33: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   [11,10]
# /var/folders/p4/6w50dy6n077b1z2n4wf2nlpc0000gn/T/ipykernel_12599/390047824.py:33: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   [11,10]
# /var/folders/p4/6w50dy6n077b1z2n4wf2nlpc0000gn/T/ipykernel_12599/390047824.py:33: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   [11,10]
# /var/folders/p4/6w50dy6n077b1z2n4wf2nlpc0000gn/T/ipykernel_12599/390047824.py:33: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   [11,10]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 33
#      28         deck_of_cards.apppend(1)
#      29     return sum(deck_of_cards) # CHECK TO SEE ABOUT THE INDENTATION!!!
#      32 test = [
# ---> 33     [11,10]
#      34     [2,4]
#      35 ]
#      37 for i in test:
#      38     print(f"{i} {calc_score(i)}")
#
# TypeError: list indices must be integers or slices, not tuple

# %%
import random


def house_deals():
    deck_of_cards = {
        "cards_clubs": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_diamonds": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_hearts": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_spades": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    }
    suit = random.choice(list(deck_of_cards.keys()))  #using the list function to get the keys of deck_of_cards
    card = random.choice(deck_of_cards[suit]) #randomly picking value of deck_of cards
    print(f"Dealt card: {card} of {suit}")
    return card


# Calculatint the score:

def calc_score(deck_of_cards):
    blackjack = sum(deck_of_cards) == 21 and len(deck_of_cards) == 2

    if blackjack:
        print(f"Congrats: BLACKJACK")
        return blackjack

    if 11 in deck_of_cards and sum(deck_of_cards) > 21:
        deck_of_cards.remove(11)
        deck_of_cards.apppend(1)
    return sum(deck_of_cards)


test = [
    [11,10],
    [2,4]
]

for i in test:
    print(f"{i} {calc_score(i)}")
# Out:
# Congrats: BLACKJACK
# [11, 10] True
# [2, 4] 6

# %%
def calc(deck):
    return sum(deck)

total = calc([2,2])

print(total)
# Out:
# 4

# %%
def calc(deck):

    if sum(deck) == 21 and len(deck) == 2:
        return "blackjack"

    return sum(deck)

# %%
import random


def house_deals():
    deck_of_cards = {
        "cards_clubs": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_diamonds": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_hearts": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
        "cards_spades": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    }
    suit = random.choice(list(deck_of_cards.keys()))  #using the list function to get the keys of deck_of_cards
    card = random.choice(deck_of_cards[suit]) #randomly picking value of deck_of cards
    print(f"Dealt card: {card} of {suit}")
    return card


# Calculatint the score:

#DOES NOT WORK
def calc_score(deck_of_cards):
    blackjack = sum(deck_of_cards) == 21 and len(deck_of_cards) == 2

    if sum(deck_of_cards) == blackjack:
        return blackjack

    if 11 in deck_of_cards and sum(deck_of_cards) > 21:
        deck_of_cards.remove(11)
        deck_of_cards.apppend(1)
    return sum(deck_of_cards) # CHECK TO SEE ABOUT THE INDENTATION!!!


test = [
    [11,10],
    [2,4]
]

for i in test:
    print(f"{i} {calc_score(i)}")
# calc_score([2,3])
# Out:
# [11, 10] 21
# [2, 4] 6

# %%
def play():
    players_card = []
    dealers_card = []

    for deal in range(2):
        players_card.append(house_deals)
        dealers_card.append(house_deals)

# %%
def compare(player_score, dealer_score):
    blackjack = sum(deck_of_cards) == 21 and len(deck_of_cards) == 2
    if player_score > 21 and dealer_score > 21:
      return "You went over. You lose "


    if player_score == dealer_score:
      return "Draw "
    elif dealer_score == blackjack:
      return "Lose, opponent has Blackjack"
    elif player_score == blackjack:
      return "Win with a Blackjack"
    elif player_score > 21:
      return "You went over. You lose"
    elif dealer_score > 21:
      return "Opponent went over. You win"
    elif player_score > dealer_score:
      return "You win"
    else:
      return "You lose"

# %%
import random




def house_deals():
    # Create deck of cards
    deck_of_cards = {
    "cards_clubs": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_diamonds": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_hearts": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_spades": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
}
    suit = random.choice(list(deck_of_cards.keys()))
    card = random.choice(deck_of_cards[suit])
    return card


def calc_score(deck_of_cards):
    blackjack = sum(deck_of_cards) == 21 and len(deck_of_cards) == 2

    if blackjack:
        print(f"Congrats: BLACKJACK")
        return blackjack

    if 11 in deck_of_cards and sum(deck_of_cards) > 21:
        deck_of_cards.remove(11)
        deck_of_cards.apppend(1)
    return sum(deck_of_cards)

############################################



def compare(player_score, dealer_score, blackjack):

	if player_score > 21 and dealer_score > 21:
		return "You went over. You lose "


	if player_score == dealer_score:
		return "Draw "
	elif dealer_score == blackjack:
		return "Lose, opponent has Blackjack"
	elif player_score == blackjack:
		return "Win with a Blackjack"
	elif player_score > 21:
		return "You went over. You lose"
	elif dealer_score > 21:
		return "Opponent went over. You win"
	elif player_score > dealer_score:
		return "You win"
	else:
		return "You lose"








test = [
    [11,10],
    [2,4]
]




for player_score, dealer_score, blackjack in test:
    result = compare(player_score, dealer_score, blackjack)
    print(f"Player: {player_score}, Dealer: {dealer_score}, Result: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 63
#      53     return "You lose"
#      55 test = [
#      56     [11,10],
#      57     [2,4]
#      58 ]
# ---> 63 for player_score, dealer_score, blackjack in test:
#      64     result = compare(player_score, dealer_score, blackjack)
#      65     print(f"Player: {player_score}, Dealer: {dealer_score}, Result: {result}")
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import random




def house_deals():
    # Create deck of cards
    deck_of_cards = {
    "cards_clubs": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_diamonds": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_hearts": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_spades": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
}
    suit = random.choice(list(deck_of_cards.keys()))
    card = random.choice(deck_of_cards[suit])
    return card
    


# Calculating
def calc_score(deck_of_cards):
    blackjack = sum(deck_of_cards) == 21 and len(deck_of_cards) == 2

    if blackjack:
        print(f"Congrats: BLACKJACK")
        return 0 #needs to be an int??

    if 11 in deck_of_cards and sum(deck_of_cards) > 21:
        deck_of_cards.remove(11)
        deck_of_cards.apppend(1)
    return sum(deck_of_cards)

################################


# Comparing hands
def compare(player_score, dealer_score):

    if player_score > 21 and dealer_score > 21:
        return "You went over. You lose "

    if player_score == dealer_score:
        return "Draw "
    elif dealer_score == 0:
        return "Lose, opponent has Blackjack"
    elif player_score == 0:
        return "Win with a Blackjack"
    elif player_score > 21:
        return "You went over. You lose"
    elif dealer_score > 21:
        return "Opponent went over. You win"
    elif player_score > dealer_score:
        return "You win"
    else:
        return "You lose"
    

test = [
    [11,10],
    [2,4]
]




for player_score, dealer_score in test:
    result = compare(player_score, dealer_score)
    print(f"Player: {player_score}, Dealer: {dealer_score}, Result: {result}")
# Out:
# Player: 11, Dealer: 10, Result: You win
# Player: 2, Dealer: 4, Result: You lose

# %%
#     players_card = []
#     dealers_card = []
#

# %%
import random

def house_deals():
    # Create deck of cards
    deck_of_cards = {
    "cards_clubs": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_diamonds": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_hearts": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_spades": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
}
    suit = random.choice(list(deck_of_cards.keys()))
    card = random.choice(deck_of_cards[suit])
    return card

def calc_score(deck_of_cards):
    blackjack = sum(deck_of_cards) == 21 and len(deck_of_cards) == 2

    if blackjack:
        print(f"Congrats: BLACKJACK")
        return 0 #needed to be int.  Does now work when i return blackjack

    if 11 in deck_of_cards and sum(deck_of_cards) > 21:
        deck_of_cards.remove(11)
        deck_of_cards.append(1)
    return sum(deck_of_cards)

def compare(player_score, dealer_score):

    if player_score > 21 and dealer_score > 21:
        return "You went over. You lose "
    if player_score == dealer_score:
        return "Its a tie"
    elif dealer_score == 0:
        return "Dealer has a Blackjack: You Loose"
    elif player_score == 0:
        return "Blackjack: You Win"
    elif player_score > 21:
        return "You went over. You Lose"
    elif dealer_score > 21:
        return "Dealer went over. You Win"
    elif player_score > dealer_score:
        return "You win"
    else:
        return "You lose"


########################

# Dealing card to dealer and player
def play():
    players_card = []
    dealers_card = []
    game_over = False

    for deal in range(2):
        players_card.append(house_deals())
        dealers_card.append(house_deals())

    while not game_over:
        player_score = calc_score(players_card)
        dealer_score = calc_score(dealers_card)
        print(f"Your cards are: {players_card}, Your current score is: {player_score}")
        print(f"Dealers first card is: {dealers_card[0]}")

        if player_score == 0 or dealer_score == 0 or player_score > 21:
            game_over = True
        else:
            hit_or_no = input("Type 'y' to get another card, type 'n' to stay").lower()
            if hit_or_no == "y":
                players_card.append(house_deals())
            else:
                game_over = True


play()
# Out:
# Your cards are: [6, 6], Your current score is: 12
# Dealers first card is: 6
# Your cards are: [6, 6, 3], Your current score is: 15
# Dealers first card is: 6

# %%
import random




def house_deals():
    # Create deck of cards
    deck_of_cards = {
    "cards_clubs": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_diamonds": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_hearts": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
    "cards_spades": [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10],
}
    suit = random.choice(list(deck_of_cards.keys()))
    card = random.choice(deck_of_cards[suit])
    return card
    
#     players_card = []
#     dealers_card = []
    


def calc_score(deck_of_cards):
    blackjack = sum(deck_of_cards) == 21 and len(deck_of_cards) == 2

    if blackjack:
        print(f"Congrats: BLACKJACK")
        return 0 #needed to be int.  Does now work when i return blackjack

    if 11 in deck_of_cards and sum(deck_of_cards) > 21:
        deck_of_cards.remove(11)
        deck_of_cards.append(1)
    return sum(deck_of_cards)

def compare(player_score, dealer_score):

    if player_score > 21 and dealer_score > 21:
        return "You went over. You lose "
    if player_score == dealer_score:
        return "Its a tie"
    elif dealer_score == 0:
        return "Dealer has a Blackjack: You Loose"
    elif player_score == 0:
        return "Blackjack: You Win"
    elif player_score > 21:
        return "You went over. You Lose"
    elif dealer_score > 21:
        return "Dealer went over. You Win"
    elif player_score > dealer_score:
        return "You win"
    else:
        return "You lose"


def play():
    players_card = []
    dealers_card = []
    game_over = False

    for deal in range(2):
        players_card.append(house_deals())
        dealers_card.append(house_deals())

    while not game_over:
        player_score = calc_score(players_card)
        dealer_score = calc_score(dealers_card)
        print(f"Your cards are: {players_card}, Your current score is: {player_score}")
        print(f"Dealers first card is: {dealers_card[0]}")

        if player_score == 0 or dealer_score == 0 or player_score > 21:
            game_over = True
        else:
            hit_or_no = input("Type 'y' to get another card, type 'n' to stay").lower()
            if hit_or_no == "y":
                players_card.append(house_deals())
            else:
                game_over = True


    while dealer_score != 0 and dealer_score < 17:
        dealers_card.append(house_deals())
        dealer_score = calc_score(dealers_card)

    print(f" Your final hand: {players_card}, final score: {player_score}")
    print(f" Computer's final hand: {dealers_card}, final score: {dealer_score}")
    print(compare(player_score, dealer_score))

    if input("Do you want to play again? Type 'y' for yes, 'n' for no: ").lower() == "y":
        play()
   
while input("Do you want to play a game of Blackjack? Type 'y' or 'n': ").lower() == "y":
    play()
# Out:
# Your cards are: [7, 10], Your current score is: 17
# Dealers first card is: 5
#  Your final hand: [7, 10], final score: 17
#  Computer's final hand: [5, 10, 4], final score: 19
# You lose
